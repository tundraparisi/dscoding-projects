# %%
import sys
sys.path.append('/Users/apple/Documents/GitHub/dscoding-projects/ayagoz.shayakhmetova/CISI-project/')
from dataI import CISIData

data_movie = CISIData()

# %%
path_movie = '/Users/apple/Documents/GitHub/dscoding-projects/ayagoz.shayakhmetova/CISI-project/cisi_project/tmdb_5000_movies.csv'
data_movie.load_data_from_csv(path_movie)

# %%
data_movie.retrieve_data()
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
data_movie.data_info()
# Out:
# 'Dataset information: 4803 rows loaded'

# %%
data_movie.get_head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
data_movie.get_tail()
# Out:
#       budget                                             genres  \
# 4798  220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# ...

# %%
data_movie.clean_column('genres')

# %%
data_movie.clean_column('keywords')

# %%
data_movie.clean_column('production_companies')

# %%
data_movie.drop_column('production_companies')

# %%
data_movie.drop_column('spoken_languages')

# %%
data_movie.show_incorrect_rows('budget')
# Out:
#       budget                              genres  \
# 265        0               Comedy Fantasy Family
# 321        0                              Comedy
# 359        0   Adventure Animation Comedy Family
# 406        0       Drama Animation Family Comedy
# 409        0                         Drama Music
# ...      ...                                 ...
# 4795       0                               Drama
# 4797       0                    Foreign Thriller
# 4800       0        Comedy Drama Romance TVMovie
# 4801       0
# 4802       0                         Documentary
#
#                                                homepage      id  \
# 265                                                 NaN   10588
# 321                                                 NaN   77953
# 359   http://www.foxmovies.com/movies/alvin-and-the-...  258509
# 406                     http://www.arthurchristmas.com/   51052
# 409                                                 NaN   16858
# ...

# %%
data_movie.remove_incorrect_rows('budget')
# Out:
#          budget                                    genres  \
# 0     237000000   Action Adventure Fantasy ScienceFiction
# 1     300000000                  Adventure Fantasy Action
# 2     245000000                    Action Adventure Crime
# 3     250000000               Action Crime Drama Thriller
# 4     260000000           Action Adventure ScienceFiction
# ...         ...                                       ...
# 4791         13                                    Horror
# 4792      20000             Crime Horror Mystery Thriller
# 4796       7000             ScienceFiction Drama Thriller
# 4798     220000                     Action Crime Thriller
# 4799       9000                            Comedy Romance
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# 1     http://disney.go.com/disneypictures/pirates/     285
# 2      http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
data_movie.show_incorrect_rows('tagline')
# Out:
#          budget                                    genres  \
# 10    270000000   Adventure Fantasy Action ScienceFiction
# 56    185000000           Action Adventure ScienceFiction
# 66    175000000         Animation Comedy Family Adventure
# 78    175000000            Family Adventure Drama Fantasy
# 128   150000000                          Thriller Mystery
# ...         ...                                       ...
# 4741      75000                            ScienceFiction
# 4755      50000                               Documentary
# 4756      50000                   Horror Thriller Fantasy
# 4759      50000                               Documentary
# 4770     500000                              Drama Comedy
#
#                                              homepage      id  \
# 10                            http://www.superman.com    1452
# 56                      http://www.startrekmovie.com/  188927
# 66            http://disney.go.com/disneypictures/up/   14160
# ...

# %%
data_movie.remove_incorrect_rows('tagline')
# Out:
#          budget                                    genres  \
# 0     237000000   Action Adventure Fantasy ScienceFiction
# 1     300000000                  Adventure Fantasy Action
# 2     245000000                    Action Adventure Crime
# 3     250000000               Action Crime Drama Thriller
# 4     260000000           Action Adventure ScienceFiction
# ...         ...                                       ...
# 4791         13                                    Horror
# 4792      20000             Crime Horror Mystery Thriller
# 4796       7000             ScienceFiction Drama Thriller
# 4798     220000                     Action Crime Thriller
# 4799       9000                            Comedy Romance
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# 1     http://disney.go.com/disneypictures/pirates/     285
# 2      http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
data_movie.retrieve_data()
# Out:
#          budget                                    genres  \
# 0     237000000   Action Adventure Fantasy ScienceFiction
# 1     300000000                  Adventure Fantasy Action
# 2     245000000                    Action Adventure Crime
# 3     250000000               Action Crime Drama Thriller
# 4     260000000           Action Adventure ScienceFiction
# ...         ...                                       ...
# 4791         13                                    Horror
# 4792      20000             Crime Horror Mystery Thriller
# 4796       7000             ScienceFiction Drama Thriller
# 4798     220000                     Action Crime Thriller
# 4799       9000                            Comedy Romance
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# 1     http://disney.go.com/disneypictures/pirates/     285
# 2      http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
new_movies = data_movie.new_csv('/Users/apple/Documents/GitHub/dscoding-projects/ayagoz.shayakhmetova/CISI-project/cisi_project/new_movies_1.csv')

# %%
new_data_movie = CISIData()

# %%
path_new_movie = '/Users/apple/Documents/GitHub/dscoding-projects/ayagoz.shayakhmetova/CISI-project/cisi_project/new_movies_1.csv'
new_data_movie.load_data_from_csv(path_new_movie)

# %%
new_data_movie.data_info()
# Out:
# 'Dataset information: 3368 rows loaded'
