# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
voters = pd.read_excel('/Users/tundra/Documents/polling_stations/data/voters.xlsx')
preferences = pd.read_excel('/Users/tundra/Documents/polling_stations/data/preferences.xlsx')
polling_stations = pd.read_excel('/Users/tundra/Documents/polling_stations/data/polling_stations.xlsx')

# %%
voters.head()
# Out:
#    Unnamed: 0    voter  discount
# 0           0  voter_1      0.09
# 1           1  voter_2      0.00
# 2           2  voter_3      0.07
# 3           3  voter_4      0.00
# 4           4  voter_5      0.10

# %%
preferences.head(50)
# Out:
#     Unnamed: 0    voter      polling_station  preference_priority
# 0            0  voter_1  polling_station_168                    1
# 1            1  voter_1  polling_station_207                    2
# 2            2  voter_1  polling_station_222                    3
# 3            3  voter_1  polling_station_124                    4
# 4            4  voter_1  polling_station_223                    5
# 5            5  voter_1  polling_station_297                    6
# 6            6  voter_1  polling_station_129                    7
# 7            7  voter_1   polling_station_12                    8
# 8            8  voter_1    polling_station_1                    9
# 9            9  voter_1  polling_station_129                   10
# 10          10  voter_1   polling_station_46                   11
# 11          11  voter_1  polling_station_343                   12
# 12          12  voter_1  polling_station_338                   13
# 13          13  voter_1   polling_station_90                   14
# 14          14  voter_1  polling_station_269                   15
# 15          15  voter_1  polling_station_237                   16
# 16          16  voter_1   polling_station_22                   17
# 17          17  voter_1   polling_station_97                   18
# 18          18  voter_2  polling_station_369                    1
# 19          19  voter_2  polling_station_138                    2
# 20          20  voter_2  polling_station_333                    3
# 21          21  voter_2  polling_station_124                    4
# 22          22  voter_2  polling_station_224                    5
# 23          23  voter_2  polling_station_166                    6
# 24          24  voter_2  polling_station_177                    7
# 25          25  voter_2    polling_station_6                    8
# 26          26  voter_2  polling_station_326                    9
# 27          27  voter_2  polling_station_267                   10
# 28          28  voter_2  polling_station_374                   11
# 29          29  voter_2  polling_station_177                   12
# 30          30  voter_2   polling_station_11                   13
# 31          31  voter_2    polling_station_1                   14
# 32          32  voter_2  polling_station_349                   15
# 33          33  voter_2  polling_station_344                   16
# 34          34  voter_2   polling_station_77                   17
# 35          35  voter_2  polling_station_368                   18
# 36          36  voter_2   polling_station_12                   19
# 37          37  voter_2  polling_station_277                   20
# 38          38  voter_2  polling_station_161                   21
# 39          39  voter_2   polling_station_79                   22
# 40          40  voter_2   polling_station_26                   23
# 41          41  voter_2  polling_station_114                   24
# 42          42  voter_2  polling_station_228                   25
# 43          43  voter_2  polling_station_142                   26
# 44          44  voter_2  polling_station_336                   27
# 45          45  voter_2  polling_station_250                   28
# 46          46  voter_2  polling_station_337                   29
# 47          47  voter_2  polling_station_146                   30
# 48          48  voter_2   polling_station_82                   31
# 49          49  voter_2  polling_station_259                   32

# %%
polling_stations.tail()
# Out:
#      Unnamed: 0      polling_station  voting_booth  station_cost
# 395         395  polling_station_396             5           212
# 396         396  polling_station_397            12            68
# 397         397  polling_station_398            14           102
# 398         398  polling_station_399            16           284
# 399         399  polling_station_400            14           145

# %%
polling_stations.describe()
# Out:
#        Unnamed: 0  voting_booth  station_cost
# count  400.000000    400.000000    400.000000
# mean   199.500000     11.542500    177.645000
# std    115.614301      4.387633     73.159379
# min      0.000000      5.000000     50.000000
# 25%     99.750000      8.000000    116.750000
# 50%    199.500000     11.000000    183.000000
# 75%    299.250000     15.000000    238.250000
# max    399.000000     19.000000    299.000000

# %% [markdown]
# STRATEGY: RANDOM ALLOCATION

# %%
class RandomVoterAllocator:
    def __init__(self, voters, polling_stations):
        self.voters = voters
        self.polling_stations = polling_stations
    
    def random_allocation(self):
        # Converti la colonna 'polling_station' in un array NumPy
        polling_stations_array = self.polling_stations['polling_station'].values
        
        # Converti la colonna 'voter' in un array NumPy
        voters_array = self.voters['voter'].values
        np.random.shuffle(voters_array)
   
        allocation = {}

        for voter in voters_array:
            station = np.random.choice(polling_stations_array)
            if station in allocation:
                allocation[station].append(voter)
            else:
                allocation[station] = [voter]
        return allocation

# Esempio di utilizzo
#voters_df =  pd.read_excel('data/voters.xlsx')
#polling_stations_df = pd.read_excel('data/preferences.xlsx')

TheRandomAllocator = RandomVoterAllocator(voters, polling_stations)
random_allocation_result = TheRandomAllocator.random_allocation()
print(random_allocation_result)
# Out:
# {'polling_station_107': ['voter_3637', 'voter_3606', 'voter_1715', 'voter_2482', 'voter_3118', 'voter_1048', 'voter_2196', 'voter_2366', 'voter_2356', 'voter_2175', 'voter_443', 'voter_3206'], 'polling_station_26': ['voter_3191', 'voter_2085', 'voter_1345', 'voter_3708', 'voter_3661', 'voter_1094', 'voter_59', 'voter_1927', 'voter_3325'], 'polling_station_360': ['voter_3844', 'voter_283', 'voter_1179', 'voter_476', 'voter_3456', 'voter_3331', 'voter_3974', 'voter_420', 'voter_3591', 'voter_3766', 'voter_1402', 'voter_3112', 'voter_1184'], 'polling_station_95': ['voter_1756', 'voter_1115', 'voter_985', 'voter_3682', 'voter_2439', 'voter_1791', 'voter_2147', 'voter_201', 'voter_3817', 'voter_3627'], 'polling_station_256': ['voter_1936', 'voter_1551', 'voter_1596', 'voter_1892', 'voter_2634', 'voter_2068', 'voter_1056', 'voter_1958', 'voter_3521', 'voter_3083', 'voter_899'], 'polling_station_120': ['voter_1124', 'voter_1515', 'voter_2506', 'voter_1320', 'voter_304', 'voter_2951', 'voter_1855', 'voter_3559'], 'polling_station_216': ['voter_1242', 'voter_2169', 'voter_3407', 'voter_3352', 'voter_2369', 'voter_2823', 'voter_300', 'voter_795', 'voter_740', 'voter_1382', 'voter_3063', 'voter_570', 'voter_1096', 'voter_2553', 'voter_662', 'voter_968', 'voter_3334', 'voter_45', 'voter_863', 'voter_3187', 'voter_1524'], 'polling_station_229': ['voter_1972', 'voter_2483', 'voter_2468', 'voter_3741', 'voter_1489', 'voter_1595', 'voter_680', 'voter_3710', 'voter_2239', 'voter_2781', 'voter_1590', 'voter_167'], 'polling_station_21': ['voter_501', 'voter_123', 'voter_3037', 'voter_2938', 'voter_509', 'voter_2859', 'voter_1772', 'voter_541'], 'polling_station_209': ['voter_2190', 'voter_169', 'voter_690', 'voter_34', 'voter_3003', 'voter_2733', 'voter_1965', 'voter_956', 'voter_844'], 'polling_station_35': ['voter_1463', 'voter_2430', 'voter_492', 'voter_1108', 'voter_2150', 'voter_3070', 'voter_2198', 'voter_413', 'voter_3397', 'voter_1734', 'voter_3811', 'voter_1591', 'voter_2695', 'voter_373', 'voter_1081', 'voter_106', 'voter_2277', 'voter_3750'], 'polling_station_118': ['voter_1166', 'voter_399', 'voter_1297', 'voter_808', 'voter_2647', 'voter_2007', 'voter_3673', 'voter_816', 'voter_3016', 'voter_3927'], 'polling_station_228': ['voter_1440', 'voter_2884', 'voter_102', 'voter_1920', 'voter_1593', 'voter_3197', 'voter_1275'], 'polling_station_129': ['voter_435', 'voter_3843', 'voter_865', 'voter_1634', 'voter_2615', 'voter_3130', 'voter_909', 'voter_1947'], 'polling_station_328': ['voter_4000', 'voter_1235', 'voter_2060', 'voter_131', 'voter_543', 'voter_934', 'voter_1481', 'voter_689', 'voter_3875', 'voter_3131', 'voter_3762', 'voter_1619', 'voter_3379', 'voter_1011', 'voter_2318'], 'polling_station_195': ['voter_3813', 'voter_2173', 'voter_1192', 'voter_3645', 'voter_3695', 'voter_2204', 'voter_1034', 'voter_3314', 'voter_77', 'voter_3351', 'voter_1277', 'voter_3789', 'voter_2234'], 'polling_station_394': ['voter_2727', 'voter_815', 'voter_318', 'voter_2898', 'voter_2622', 'voter_639', 'voter_2960', 'voter_1458', 'voter_3117', 'voter_3860'], 'polling_station_222': ['voter_3536', 'voter_28', 'voter_2156', 'voter_1898', 'voter_1150', 'voter_1392', 'voter_2260', 'voter_2095'], 'polling_station_60': ['voter_1934', 'voter_344', 'voter_275', 'voter_1978', 'voter_3950', 'voter_1970', 'voter_355', 'voter_299', 'voter_996', 'voter_2654', 'voter_1866', 'voter_1224', 'voter_2958'], 'polling_station_340': ['voter_3936', 'voter_945', 'voter_1095', 'voter_2850', 'voter_1730', 'voter_2003', 'voter_2653', 'voter_1724', 'voter_132', 'voter_2251', 'voter_2693', 'voter_2721', 'voter_1425'], 'polling_station_205': ['voter_2690', 'voter_829', 'voter_1253', 'voter_1570', 'voter_1', 'voter_626', 'voter_1883', 'voter_2805', 'voter_1371', 'voter_3724'], 'polling_station_1': ['voter_1446', 'voter_3922', 'voter_281', 'voter_2281', 'voter_3613', 'voter_2032', 'voter_3050', 'voter_282', 'voter_120', 'voter_471', 'voter_3821', 'voter_1047'], 'polling_station_258': [' ...

# %%
# a dataframe is built to better check the results
allocation_df = pd.DataFrame(list(random_allocation_result.items()), columns=['Station', 'Voters'])
allocation_df
# Out:
#                  Station                                             Voters
# 0    polling_station_107  [voter_3637, voter_3606, voter_1715, voter_248...
# 1     polling_station_26  [voter_3191, voter_2085, voter_1345, voter_370...
# 2    polling_station_360  [voter_3844, voter_283, voter_1179, voter_476,...
# 3     polling_station_95  [voter_1756, voter_1115, voter_985, voter_3682...
# 4    polling_station_256  [voter_1936, voter_1551, voter_1596, voter_189...
# ..                   ...                                                ...
# 395  polling_station_273  [voter_3582, voter_2419, voter_705, voter_3128...
# 396  polling_station_292     [voter_1931, voter_151, voter_1962, voter_237]
# 397    polling_station_4  [voter_3891, voter_3541, voter_3467, voter_264...
# 398  polling_station_139  [voter_1310, voter_2908, voter_82, voter_2129,...
# 399  polling_station_122                           [voter_1574, voter_3386]
#
# [400 rows x 2 columns]

# %%
stations_extraction = list(random_allocation_result.keys())
num_voters_extraction = [len(voters) for voters in random_allocation_result.values()]

# creating a bar graph
plt.bar(stations_extraction, num_voters_extraction)
plt.xlabel('Stations')
plt.ylabel('Number of voters assigned')
plt.title('Random allocation of voters to stations')
plt.xticks(rotation=45)
plt.show()

# %%
stations_extraction = list(random_allocation_result.keys())
num_voters_extraction = [len(voters) for voters in random_allocation_result.values()]

plt.barh(stations_extraction, num_voters_extraction)
plt.xlabel('Number of voters assigned')
plt.ylabel('Number of voters assigned')
plt.title('Random allocation of voters to stations')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# STRATEGY: ALLOCATION BASED ON PREFERENCES

# %%
polling_stations.head()
# Out:
#    Unnamed: 0    polling_station  voting_booth  station_cost
# 0           0  polling_station_1            13           273
# 1           1  polling_station_2            18            92
# 2           2  polling_station_3            12           141
# 3           3  polling_station_4            18           157
# 4           4  polling_station_5             7           298

# %%
class PreferenceVoterAllocator:
    def __init__(self, voters, preferences, polling_stations):
        self.voters = voters
        self.preferences = preferences
        self.polling_stations = polling_stations
        self.allocation_result = None
        self.station_capacity = None 

    def initialise_station_capacity(self):
        self.station_capacity = {}
        for _, row in self.polling_stations.iterrows():
            self.station_capacity[row['polling_station']] = row['voting_booth']

    def preference_based_allocation(self):
        allocation = {}
        sorted_preferences = self.preferences.sort_values(by=['voter','preference_priority'])

        for _, row in sorted_preferences.iterrows():
            voter = row['voter']
            station = row['polling_station']

            if self.station_capacity[station] > 0:
                if voter in allocation:
                    allocation[voter].append(station)
                else:
                    allocation[voter] = [station]
                self.station_capacity[station] -= 1

        self.allocation_result = allocation

    def print_allocation_result(self):
        if self.allocation_result:
            print(self.allocation_result)
        else:
            print("Run allocation first.")

preference_voter_allocator = PreferenceVoterAllocator(voters, preferences, polling_stations)
preference_voter_allocator.initialise_station_capacity()
preference_voter_allocator.preference_based_allocation()

preference_voter_allocator.print_allocation_result()
# Out:
# {'voter_1': ['polling_station_168', 'polling_station_207', 'polling_station_222', 'polling_station_124', 'polling_station_223', 'polling_station_297', 'polling_station_129', 'polling_station_12', 'polling_station_1', 'polling_station_129', 'polling_station_46', 'polling_station_343', 'polling_station_338', 'polling_station_90', 'polling_station_269', 'polling_station_237', 'polling_station_22', 'polling_station_97'], 'voter_10': ['polling_station_60', 'polling_station_317', 'polling_station_95', 'polling_station_22', 'polling_station_319', 'polling_station_279', 'polling_station_275', 'polling_station_185', 'polling_station_370', 'polling_station_95', 'polling_station_292', 'polling_station_294', 'polling_station_391', 'polling_station_350', 'polling_station_260', 'polling_station_265', 'polling_station_344', 'polling_station_343', 'polling_station_292', 'polling_station_316', 'polling_station_123', 'polling_station_262', 'polling_station_58', 'polling_station_241', 'polling_station_68', 'polling_station_233', 'polling_station_332'], 'voter_100': ['polling_station_73', 'polling_station_154', 'polling_station_45', 'polling_station_377', 'polling_station_141', 'polling_station_75', 'polling_station_300', 'polling_station_44', 'polling_station_215', 'polling_station_20', 'polling_station_112', 'polling_station_120', 'polling_station_61', 'polling_station_131', 'polling_station_147', 'polling_station_313', 'polling_station_87', 'polling_station_381', 'polling_station_100', 'polling_station_59', 'polling_station_154', 'polling_station_342', 'polling_station_266', 'polling_station_378', 'polling_station_369', 'polling_station_381', 'polling_station_92', 'polling_station_313', 'polling_station_264', 'polling_station_365', 'polling_station_300', 'polling_station_279', 'polling_station_45', 'polling_station_93', 'polling_station_344', 'polling_station_22'], 'voter_1000': ['polling_station_396', 'polling_station_7', 'polling_station_391', 'polling_station_351', 'polling_station_102', 'polling_station_147', 'polling_station_184', 'polling_station_224', 'polling_station_46', 'polling_station_106', 'polling_station_261', 'polling_station_115', 'polling_station_77', 'polling_station_151', 'polling_station_192', 'polling_station_302', 'polling_station_124', 'polling_station_269', 'polling_station_152', 'polling_station_129', 'polling_station_5', 'polling_station_142', 'polling_station_196', 'polling_station_12', 'polling_station_121', 'polling_station_27', 'polling_station_5', 'polling_station_66', 'polling_station_256', 'polling_station_20', 'polling_station_174', 'polling_station_87', 'polling_station_240', 'polling_station_20', 'polling_station_137', 'polling_station_399', 'polling_station_381', 'polling_station_32', 'polling_station_68', 'polling_station_333', 'polling_station_155', 'polling_station_306', 'polling_station_103', 'polling_station_232', 'polling_station_207', 'polling_station_55', 'polling_station_143'], 'voter_1001': ['polling_station_109', 'polling_station_52', 'polling_station_33', 'polling_station_204', 'polling_station_249', 'polling_station_198', 'polling_station_208', 'polling_station_306', 'polling_station_18', 'polling_station_97', 'polling_station_304', 'polling_station_135', 'polling_station_211', 'polling_station_390', 'polling_station_83', 'polling_station_260', 'polling_station_330', 'polling_station_337', 'polling_station_246', 'polling_station_85', 'polling_station_296', 'polling_station_266', 'polling_station_91', 'polling_station_344', 'polling_station_303', 'polling_station_245', 'polling_station_115', 'polling_station_215', 'polling_station_331', 'polling_station_139', 'polling_station_159', 'polling_station_48', 'polling_station_295', 'polling_station_123', 'polling_station_195', 'polling_station_196', 'polling_station_42', 'polling_station_25', 'polling_station_126', 'polling_station_272', 'polling_station_140'], 'voter_1002': ['polling_station_88', 'polling_station_219', 'polling_station_34', 'polling ...

# %%
print(type(preference_voter_allocator.allocation_result))
# Out:
# <class 'dict'>

# %%
preference_allocation_result = pd.DataFrame.from_dict(preference_voter_allocator.allocation_result, orient='index')
#preference_allocation_result.head()

# %%
print(type(preference_allocation_result))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
preference_allocation_result.head(10)
# Out:
#                              0                    1                    2   \
# voter_1     polling_station_168  polling_station_207  polling_station_222
# voter_10     polling_station_60  polling_station_317   polling_station_95
# voter_100    polling_station_73  polling_station_154   polling_station_45
# voter_1000  polling_station_396    polling_station_7  polling_station_391
# voter_1001  polling_station_109   polling_station_52   polling_station_33
# voter_1002   polling_station_88  polling_station_219   polling_station_34
# voter_1003   polling_station_35   polling_station_87  polling_station_113
# voter_1004    polling_station_9  polling_station_152   polling_station_74
# voter_1005  polling_station_330  polling_station_243  polling_station_382
# voter_1006   polling_station_64  polling_station_381  polling_station_287
#
#                              3                    4                    5   \
# voter_1     polling_station_124  polling_station_223  polling_station_297
# voter_10     polling_station_22  polling_station_319  polling_station_279
# voter_100   polling_station_377  polling_station_141   polling_station_75
# voter_1000  polling_station_351  polling_station_102  polling_station_147
# voter_1001  polling_station_204  polling_station_249  polling_station_198
# voter_1002  polling_station_141  polling_station_362  polling_station_177
# voter_1003  polling_station_128   polling_station_58  polling_station_284
# voter_1004   polling_station_30   polling_station_94  polling_station_168
# voter_1005  polling_station_252   polling_station_74    polling_station_8
# voter_1006   polling_station_52   polling_station_71  polling_station_352
#
#                              6                    7                    8   \
# voter_1     polling_station_129   polling_station_12    polling_station_1
# voter_10    polling_station_275  polling_station_185  polling_station_370
# voter_100   polling_station_300   polling_station_44  polling_station_215
# voter_1000  polling_station_184  polling_station_224   polling_station_46
# voter_1001  polling_station_208  polling_station_306   polling_station_18
# voter_1002   polling_station_91   polling_station_55  polling_station_215
# voter_1003  polling_station_382   polling_station_32                 None
# voter_1004  polling_station_201  polling_station_263  polling_station_236
# voter_1005  polling_station_162  polling_station_340  polling_station_102
# voter_1006   polling_station_25   polling_station_42   polling_station_11
#
#                              9   ...                  37                   38  \
# voter_1     polling_station_129  ...                None                 None
# voter_10     polling_station_95  ...                None                 None
# voter_100    polling_station_20  ...                None                 None
# voter_1000  polling_station_106  ...  polling_station_32   polling_station_68
# voter_1001   polling_station_97  ...  polling_station_25  polling_station_126
# voter_1002  polling_station_199  ...                None                 None
# voter_1003                 None  ...                None                 None
# voter_1004  polling_station_339  ...                None                 None
# voter_1005  polling_station_197  ...                None                 None
# voter_1006  polling_station_342  ...                None                 None
#
#                              39                   40                   41  \
# voter_1                    None                 None                 None
# voter_10                   None                 None                 None
# voter_100                  None                 None                 None
# voter_1000  polling_station_333  polling_station_155  polling_station_306
# voter_1001  polling_station_272  polling_station_140                 None
# voter_1002                 None                 None                 None
# voter_1003                 None                 None                 None
# voter_1004                 None                 None                 None
# voter_1005                 None                 None                 None
# voter_1006                 None                 None                 None
#
#                              42                   43                   44  \
# voter_1                    None                 None                 None
# voter_10                   None                 None                 None
# voter_100                  None                 None                 None
# voter_1000  polling_station_103  polling_station_232  polling_station_207
# voter_1001                 None                 None                 None
# voter_1002                 None                 None                 None
# voter_1003                 None                 None                 None
# voter_1004                 None                 None                 None
# voter_1005                 None                 None                 None
# voter_1006                 None                 None                 None
#
#                             45                   46
# voter_1                   None                 None
# voter_10                  None                 None
# voter_100                 None                 None
# voter_1000  polling_station_55  polling_station_143
# voter_1001                None                 None
# voter_1002                None                 None
# voter_1003                None                 None
# voter_1004                None                 None
# voter_1005                None                 None
# voter_1006                None                 None
#
# [10 rows x 47 columns]

# %%
num_rows = preference_allocation_result.shape[0]
print("Number of rows: ", num_rows)
# Out:
# Number of rows:  354

# %%
# number of voters assigned to each station
preferences_allocation_counts = preference_allocation_result.count()

plt.bar(preferences_allocation_counts.index, preferences_allocation_counts.values)
plt.xlabel('Polling Stations')
plt.ylabel('Voters Assigned')
plt.title('Allocation of voters to voting stations')
plt.show()

# %% [markdown]
# STRATEGY: PRICE BASED ALLOCATION 🏦

# %%
voters.columns
# Out:
# Index(['Unnamed: 0', 'voter', 'discount'], dtype='object')

# %%
polling_stations.columns
# Out:
# Index(['Unnamed: 0', 'polling_station', 'voting_booth', 'station_cost'], dtype='object')

# %%
preferences.columns
# Out:
# Index(['Unnamed: 0', 'voter', 'polling_station', 'preference_priority'], dtype='object')

# %%
class PriceHotelAllocation:
    def __init__(self, voters, polling_stations):
        self.voters = voters
        self.polling_stations = polling_stations
        self.allocation = {}  # Dictionary to store the assignment of voters to polling stations
        self.station_capacity = {}  # Dictionary to track the remaining capacity of each polling station

    def price_based_allocation(self):
        # Initialize the capacity of polling stations
        for _, row in self.polling_stations.iterrows():
            self.station_capacity[row['polling_station']] = row['voting_booth']

        # Sort polling stations by price (from cheapest to most expensive)
        sorted_stations = self.polling_stations.sort_values(by='station_cost')

        # Iterate through voters and assign them to polling stations based on price and capacity
        for _, row in self.voters.iterrows():
            voter = row['voter']
            discount = row['discount']

            # Calculate the maximum price the voter is willing to pay
            max_price = 1 - discount

            # Find the first available polling station with a price less than or equal to the maximum price
            for _, station_row in sorted_stations.iterrows():
                station = station_row['polling_station']
                station_cost = station_row['station_cost']

                if station_cost <= max_price and self.station_capacity[station] > 0:
                    # Assign the voter to the polling station
                    if voter in self.allocation:
                        self.allocation[voter].append(station)
                    else:
                        self.allocation[voter] = [station]
                    # Update the capacity of the polling station
                    self.station_capacity[station] -= 1
                    break

        return self.allocation


# Example usage:
# Assuming you have 'voters' and 'polling_stations' DataFrames
hotel_allocator = PriceHotelAllocation(voters, polling_stations)
price_allocation_result = hotel_allocator.price_based_allocation()
print(price_allocation_result)
# Out:
# {}

# %%
price_allocation_result
# Out:
# {}

# %%
def availability_based_allocation(voters, polling_stations):
    sorted_stations = sorted(polling_stations, key=lambda x: x['capacity'], reverse=True)
    allocation = {}
    for voter in voters:
        for station in sorted_stations:
            if station['id'] not in allocation:
                allocation[station['id']] = []
            if len(allocation[station['id']]) < station['capacity']:
                allocation[station['id']].append(voter)
                break
    return allocation

# %%
# ALTRA VERSIONE

import pandas as pd

def availability_based_allocation(voters, stations):
    allocation = {}  # Dizionario per memorizzare l'assegnazione dei votanti ai seggi
    station_capacity = {}  # Dizionario per tracciare la capacità rimanente di ciascun seggio
    
    # Inizializza la capacità dei seggi
    for _, row in stations.iterrows():
        station_capacity[row['stations']] = row['station_rooms']
    
    # Ordina i seggi in base alla capacità (dal più capiente al meno capiente)
    sorted_stations = stations.sort_values(by='station_rooms', ascending=False)
    
    # Itera attraverso i votanti e assegnali ai seggi in base alla capacità e alla preferenza
    for _, row in voters.iterrows():
        voter = row['voter']
        discount = row['discount']
        
        # Calcola la preferenza massima del votante (inversamente proporzionale alla capacità)
        max_preference = 1 / (station_capacity[row['preferred_station']] + 1) * (1 - discount)
        
        # Trova il primo seggio disponibile con preferenza maggiore o uguale alla preferenza massima
        for _, station_row in sorted_stations.iterrows():
            station = station_row['stations']
            station_preference = 1 / (station_capacity[station] + 1)
            
            if station_preference >= max_preference and station_capacity[station] > 0:
                # Assegna il votante al seggio
                if voter in allocation:
                    allocation[voter].append(station)
                else:
                    allocation[voter] = [station]
                # Aggiorna la capacità del seggio
                station_capacity[station] -= 1
                break
    
    return allocation

# Esempio di utilizzo della funzione
voters_df = pd.read_csv('Voters.csv')
voters_df['preferred_station'] = voters_df.apply(lambda row: row['voter'].split('_')[1], axis=1)  # Estrapola la stazione preferita dal nome del votante
stations_df = pd.read_csv('Stations.csv')

allocation_result = availability_based_allocation(voters_df, stations_df)
print(allocation_result)
