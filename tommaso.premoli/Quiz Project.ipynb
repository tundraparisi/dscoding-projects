# %% [markdown]
# ## Data Import

# %%
import pandas as pd

# %%
movies = pd.read_excel('Dataset/Movie_Dataset.xlsx')

# %%
movies
# Out:
#                                      movie_title  year      director_name  \
# 0                                       Avatar   2009      James Cameron
# 1     Pirates of the Caribbean: At World's End   2007     Gore Verbinski
# 2                                      Spectre   2015         Sam Mendes
# 3                        The Dark Knight Rises   2012  Christopher Nolan
# 4                                  John Carter   2012     Andrew Stanton
# ...                                          ...   ...                ...
# 4929                                 Newlyweds   2011       Edward Burns
# 4930                   Signed Sealed Delivered   2013        Scott Smith
# 4931                      A Plague So Pleasant   2013   Benjamin Roberds
# 4932                          Shanghai Calling   2012        Daniel Hsia
# 4933                         My Date with Drew   2004           Jon Gunn
#
#            actor_name                           genres country
# ...
