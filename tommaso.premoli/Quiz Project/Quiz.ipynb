# %% [markdown]
# ## Data Import

# %%
import pandas as pd

# %%
movies = pd.read_excel('Dataset/Movie_Dataset.xlsx')

# %%
movies
# Out:
#                                             movie_title    year  \
# 0                                                Avatar  2009.0
# 1              Pirates of the Caribbean: At World's End  2007.0
# 2                                               Spectre  2015.0
# 3                                 The Dark Knight Rises  2012.0
# 4     Star Wars: Episode VII - The Force Awakens    ...     NaN
# ...                                                 ...     ...
# 5038                            Signed Sealed Delivered  2013.0
# 5039                          The Following                 NaN
# 5040                               A Plague So Pleasant  2013.0
# 5041                                   Shanghai Calling  2012.0
# 5042                                  My Date with Drew  2004.0
#
#           director_name       actor_name                           genres  \
# 0         James Cameron      CCH Pounder  Action|Adventure|Fantasy|Sci-Fi
# 1        Gore Verbinski      Johnny Depp         Action|Adventure|Fantasy
# 2            Sam Mendes  Christoph Waltz        Action|Adventure|Thriller
# 3     Christopher Nolan        Tom Hardy                  Action|Thriller
# 4           Doug Walker      Doug Walker                      Documentary
# ...                 ...              ...                              ...
# 5038        Scott Smith      Eric Mabius                     Comedy|Drama
# 5039                NaN      Natalie Zea     Crime|Drama|Mystery|Thriller
# 5040   Benjamin Roberds      Eva Boehnke            Drama|Horror|Thriller
# 5041        Daniel Hsia        Alan Ruck             Comedy|Drama|Romance
# 5042           Jon Gunn      John August                      Documentary
#
#      country
# 0        USA
# 1        USA
# 2         UK
# 3        USA
# 4        NaN
# ...      ...
# 5038  Canada
# 5039     USA
# 5040     USA
# 5041     USA
# 5042     USA
#
# [5043 rows x 6 columns]

# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd

movies['genres'] = movies['genres'].str.lower()

def format_genres(genres):
 genres = genres.split('|')
 if len(genres) > 1:
     genres = ', '.join(genres[:-1]) + ' and ' + genres[-1]
 else:
     genres = genres[0]
 return genres

movies['genres'] = movies['genres'].apply(format_genres)

movies.dropna(inplace=True)

movies['year'] = pd.to_numeric(movies['year'], errors='coerce').fillna(0).astype(int)

# %%
movies
# Out:
#                                    movie_title  year      director_name  \
# 0                                       Avatar  2009      James Cameron
# 1     Pirates of the Caribbean: At World's End  2007     Gore Verbinski
# 2                                      Spectre  2015         Sam Mendes
# 3                        The Dark Knight Rises  2012  Christopher Nolan
# 5                                  John Carter  2012     Andrew Stanton
# ...                                        ...   ...                ...
# 5037                                 Newlyweds  2011       Edward Burns
# 5038                   Signed Sealed Delivered  2013        Scott Smith
# 5040                      A Plague So Pleasant  2013   Benjamin Roberds
# 5041                          Shanghai Calling  2012        Daniel Hsia
# 5042                         My Date with Drew  2004           Jon Gunn
#
#            actor_name                                 genres country
# 0         CCH Pounder  action, adventure, fantasy and sci-fi     USA
# 1         Johnny Depp          action, adventure and fantasy     USA
# 2     Christoph Waltz         action, adventure and thriller      UK
# 3           Tom Hardy                    action and thriller     USA
# 5        Daryl Sabara           action, adventure and sci-fi     USA
# ...               ...                                    ...     ...
# 5037      Kerry Bishé                       comedy and drama     USA
# 5038      Eric Mabius                       comedy and drama  Canada
# 5040      Eva Boehnke             drama, horror and thriller     USA
# 5041        Alan Ruck              comedy, drama and romance     USA
# 5042      John August                            documentary     USA
#
# [4927 rows x 6 columns]

# %% [markdown]
# ## Program Creation

# %%
import pandas as pd
from numpy import random
import string
import matplotlib.pyplot as plt
import time

movies = pd.read_excel('Dataset/Movie_Dataset.xlsx')

# Data Cleaning
movies['genres'] = movies['genres'].str.lower()


def format_genres(genres):
    genres = genres.split('|')
    if len(genres) > 1:
        genres = ', '.join(genres[:-1]) + ' and ' + genres[-1]
    else:
        genres = genres[0]
    return genres


movies['genres'] = movies['genres'].apply(format_genres)
movies.dropna(inplace=True)
movies['year'] = pd.to_numeric(movies['year'], errors='coerce').fillna(0).astype(int)


def choose_difficulty():
    difficulty = input("Choose your difficulty level (Easy/Difficult): ").lower()
    if difficulty == 'easy':
        return movies['year'] > 1990, 5 * 60
    elif difficulty == 'difficult':
        return movies['year'] < 1990, 3 * 60
    else:
        print("Invalid choice, defaulting to Easy")
        return movies['year'] > 1990, 5 * 60 

def generate_question(movies, difficulty_filter):
    correct_movie = movies[difficulty_filter].sample(1)
    question = f"What is the title of the film released in {correct_movie['year'].values[0]} directed by {correct_movie['director_name'].values[0]}, starring {correct_movie['actor_name'].values[0]}, produced in {correct_movie['country'].values[0]} and belonging to the genre {correct_movie['genres'].values[0]}?"
    return question, correct_movie


def generate_answers(movies, correct_movie):
    incorrect_movies = movies.drop(correct_movie.index.values.tolist())
    incorrect_answers = incorrect_movies.sample(3)['movie_title'].values
    correct_answer = correct_movie['movie_title'].values[0]
    answers = [correct_answer] + list(incorrect_answers)
    random.shuffle(answers)
    return answers


def quiz(movies):
    difficulty_filter, time_limit = choose_difficulty()
    start_time = time.time()
    score = 0
    score_history = [0]

    for i in range(1, 11):
        elapsed_time = time.time() - start_time
        remaining_time = max(0, time_limit - elapsed_time)
        print(f"\nTime remaining: {int(remaining_time // 60)} minutes {int(remaining_time % 60)} seconds\n")

        question, correct_movie = generate_question(movies, difficulty_filter)
        answers = generate_answers(movies, correct_movie)
        print(f"Question {i}. {question}")

        for j, answer in zip(string.ascii_uppercase, answers):
            print(f"{j}. {answer}")

        user_answer = input("Your answer: ").upper()
        while user_answer not in string.ascii_uppercase:
            print("You have another chance, try again!")
            user_answer = input("Your answer: ").upper()

        correct_answer = correct_movie['movie_title'].values[0]
        selected_answer = answers[string.ascii_uppercase.index(user_answer)]
        if selected_answer == correct_answer:
            print("Correct!\n")
            score += 1
            score_history.append(score)
        else:
            print(f"Wrong! The correct answer is {correct_answer}\n")
            score_history.append(score)

        elapsed_time = time.time() - start_time
        if elapsed_time > time_limit:
            print("Time's up!")
            break

    print(f"\nYour total score is {score}/10!\n")
    plt.plot(score_history)
    plt.xlabel('Question number')
    plt.ylabel('Score')
    plt.title('Score over time')
    plt.ylim(0, 10)
    plt.show()
    retry = input("Do you want to retry? (yes/no): ").lower()
    if retry != 'no':
        quiz(movies)
    else:
        print("\nThanks for trying!")

quiz(movies)
# Out:
# Choose your difficulty level (Easy/Difficult): easy
#
# Time remaining: 4 minutes 59 seconds
#
# Question 1. What is the title of the film released in 2003 directed by David Dobkin, starring Fann Wong, produced in USA and belonging to the genre action, adventure and comedy?
# A. Shanghai Knights
# B. Teacher's Pet
# C. Killing Them Softly
# D. Regression
# Your answer: a
# Correct!
#
#
# Time remaining: 4 minutes 56 seconds
#
# Question 2. What is the title of the film released in 2001 directed by Joe Johnston, starring Michael Jeter, produced in USA and belonging to the genre action, adventure, sci-fi and thriller?
# A. Jurassic Park III
# B. The Cotton Club
# C. The Muse
# D. Littleman
# Your answer: b
# Wrong! The correct answer is Jurassic Park III
#
#
# Time remaining: 4 minutes 55 seconds
#
# Question 3. What is the title of the film released in 2013 directed by Mike Flanagan, starring James Lafferty, produced in USA and belonging to the genre horror and mystery?
# A. Cloudy with a Chance of Meatballs 2
# B. Oculus
# C. Hellraiser
# D. Beyond Borders
# Your answer: a
# Wrong! The correct answer is Oculus
#
#
# Time remaining: 4 minutes 54 seconds
#
# Question 4. What is the title of the film released in 2009 directed by Sam Taylor-Johnson, starring Kristin Scott Thomas, produced in UK and belonging to the genre biography, drama and music?
# A. Eternal Sunshine of the Spotless Mind
# B. Road Trip
# C. Nowhere Boy
# D. Delivery Man
# Your answer: a
# Wrong! The correct answer is Nowhere Boy
#
#
# Time remaining: 4 minutes 54 seconds
#
# Question 5. What is the title of the film released in 2010 directed by Reinhard Klooss, starring Jim Broadbent, produced in Germany and belonging to the genre animation, comedy and family?
# A. An Unfinished Life
# B. The Saint
# C. Blade: Trinity
# D. Animals United
# Your answer: a
# Wrong! The correct answer is Animals United
#
#
# Time remaining: 4 minutes 53 seconds
#
# Question 6. What is the title of the film released in 2000 directed by Mamoru Hosoda, starring Lara Jill Miller, produced in USA and belonging to the genre action, adventure, animation, family and sci-fi?
# A. Digimon: The Movie
# B. ZMD: Zombies of Mass Destruction
# C. The Express
# D. Animal House
# Your answer: a
# Correct!
#
#
# Time remaining: 4 minutes 53 seconds
#
# Question 7. What is the title of the film released in 2004 directed by Donald Petrie, starring Rip Torn, produced in USA and belonging to the genre comedy and romance?
# A. August Rush
# B. Tomorrowland
# C. Silent House
# D. Welcome to Mooseport
# Your answer:
# Wrong! The correct answer is Welcome to Mooseport
#
#
# Time remaining: 4 minutes 53 seconds
#
# Question 8. What is the title of the film released in 2000 directed by Brian Levant, starring Taylor Negron, produced in USA and belonging to the genre comedy, family, romance and sci-fi?
# A. The Peacemaker
# B. The Flintstones in Viva Rock Vegas
# C. Born on the Fourth of July
# D. 24 7: Twenty Four Seven
# Your answer: a
# Wrong! The correct answer is The Flintstones in Viva Rock Vegas
#
#
# Time remaining: 4 minutes 51 seconds
#
# Question 9. What is the title of the film released in 2004 directed by Peter Chelsom, starring Lisa Ann Walter, produced in USA and belonging to the genre comedy, drama and romance?
# A. Men with Brooms
# B. Coraline
# C. The Prestige
# D. Shall We Dance
# Your answer: a
# Wrong! The correct answer is Shall We Dance
#
#
# Time remaining: 4 minutes 50 seconds
#
# Question 10. What is the title of the film released in 2002 directed by Karen Moncrieff, starring Frances Fisher, produced in USA and belonging to the genre drama?
# A. The Royal Tenenbaums
# B. Underworld: Rise of the Lycans
# C. The Cookout
# D. Blue Car
# Your answer: a
# Wrong! The correct answer is Blue Car
#
#
# Your total score is 2/10!
