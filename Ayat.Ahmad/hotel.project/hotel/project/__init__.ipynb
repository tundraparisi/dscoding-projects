# %%
import pandas as pd
    pd.read_excel(r"C:\Users\ayata\Desktop\DSE\Coding for Data Science and Data Management\Python\Project\hotels\guests.xlsx")
# Out:
#       Unnamed: 0       guest  discount
# 0              0     guest_1      0.09
# 1              1     guest_2      0.00
# 2              2     guest_3      0.07
# 3              3     guest_4      0.00
# 4              4     guest_5      0.10
# ...          ...         ...       ...
# 3995        3995  guest_3996      0.00
# 3996        3996  guest_3997      0.15
# 3997        3997  guest_3998      0.07
# 3998        3998  guest_3999      0.08
# 3999        3999  guest_4000      0.07
#
# [4000 rows x 3 columns]
